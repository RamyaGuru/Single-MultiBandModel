# %%
import qualityFactor as spb
import numpy as np
import matplotlib.pyplot as plt

# %%
n_eta = 100
pf = np.zeros(n_eta)
muW = 141.5
T = 300

# %%
i = 0
eta_array = np.linspace(-8, 8, n_eta)
for eta in eta_array:
    pf[i] = spb.powerfactor(141.5, eta, T)
    i = i+1

# %%
plt.plot(eta_array, pf)
plt.show()
